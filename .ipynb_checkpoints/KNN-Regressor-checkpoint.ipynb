# %%
import pandas as pd
import numpy as np
import csv

# %%
pdf = pd.read_csv('C:\Users\sumed\Desktop\Fd_python.csv')

# %%
pdf
# Out:
#         ﻿UserID         ISBN  Rating Author_stndr_values  Age_Stanrd  \
# 0        184299  99975207021       7          0.88540709    0.356322
# 1        199025  99975122621       2         0.907268362    0.402299
# 2         23902  99975080521       6          0.50520993    0.402299
# 3         36836  99975027121       2         0.646363265    0.643678
# 4         69405  99974962321       3         0.228598427    0.413793
# 5        203799  99974129421       3         0.715037287    0.620690
# 6        184299  99974097121       4         0.885381551    0.356322
# 7        184299  99974092321       7         0.830651752    0.356322
# 8        143175  99974092321       7         0.830651752    0.321839
# 9         94923  99974050321       8         0.149657779    0.459770
# 10       217740  99905828421       7         0.481867402    0.425287
# 11       239594  99795107921       2         0.082184084    0.321839
# 12        98297  99795107921       4         0.082184084    0.275862
# ...

# %%
pdf.count()
# Out:
# ﻿UserID                193800
# ISBN                   193800
# Rating                 193800
# Author_stndr_values    193797
# Age_Stanrd             193800
# Cntry_Stnd             193800
# dtype: int64

# %%
pdf.columns=['UserID','ISBN','Rating','Author','Age','Country']
pdf
# Out:
#         UserID         ISBN  Rating       Author       Age   Country
# 0       184299  99975207021       7   0.88540709  0.356322  0.950055
# 1       199025  99975122621       2  0.907268362  0.402299  0.950055
# 2        23902  99975080521       6   0.50520993  0.402299  0.932773
# 3        36836  99975027121       2  0.646363265  0.643678  0.950055
# 4        69405  99974962321       3  0.228598427  0.413793  0.638655
# 5       203799  99974129421       3  0.715037287  0.620690  0.950055
# 6       184299  99974097121       4  0.885381551  0.356322  0.950055
# 7       184299  99974092321       7  0.830651752  0.356322  0.950055
# 8       143175  99974092321       7  0.830651752  0.321839  0.950055
# 9        94923  99974050321       8  0.149657779  0.459770  0.950055
# 10      217740  99905828421       7  0.481867402  0.425287  0.831933
# 11      239594  99795107921       2  0.082184084  0.321839  0.092437
# 12       98297  99795107921       4  0.082184084  0.275862  0.310924
# ...

# %%
cdf=pdf[['Rating','Author','Age','Country']]
cdf
# Out:
#         Rating       Author       Age   Country
# 0            7   0.88540709  0.356322  0.950055
# 1            2  0.907268362  0.402299  0.950055
# 2            6   0.50520993  0.402299  0.932773
# 3            2  0.646363265  0.643678  0.950055
# 4            3  0.228598427  0.413793  0.638655
# 5            3  0.715037287  0.620690  0.950055
# 6            4  0.885381551  0.356322  0.950055
# 7            7  0.830651752  0.356322  0.950055
# 8            7  0.830651752  0.321839  0.950055
# 9            8  0.149657779  0.459770  0.950055
# 10           7  0.481867402  0.425287  0.831933
# 11           2  0.082184084  0.321839  0.092437
# 12           4  0.082184084  0.275862  0.310924
# 13           8  0.082184084  0.482759  0.310924
# 14           8  0.393451834  0.540230  0.588235
# 15           9  0.694018797  0.287356  0.950055
# 16           8  0.452880785  0.586207  0.831933
# 17           5  0.424098478  0.206897  0.731092
# 18          10  0.249591378  0.402299  0.831933
# ...

# %%
X=cdf[['Author','Age','Country']]
y=cdf[['Rating']]

# %%
import sklearn

# %%
from sklearn.cross_validation import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
X_train=X_train._get_numeric_data()
X_train.count()
# Out:
# Age        129846
# Country    129846
# dtype: int64

# %%
X_test=X_test._get_numeric_data()
X_test.count()
# Out:
# Age        63954
# Country    63954
# dtype: int64

# %%
y_train=y_train._get_numeric_data()
y_train.count()
# Out:
# Rating    129846
# dtype: int64

# %%
y_test=y_test._get_numeric_data()
y_test.count()
# Out:
# Rating    63954
# dtype: int64

# %%
from sklearn.neighbors import KNeighborsRegressor
neigh = KNeighborsRegressor(n_neighbors=40)
neigh.fit(X_train, y_train)
# Out:
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#           metric_params=None, n_jobs=1, n_neighbors=40, p=2,
#           weights='uniform')

# %%
y_pred= neigh.predict(X_test)

# %%
neigh.score(X_test,y_test)
# Out:
# -0.011155051584671226

# %%
from sklearn.metrics import mean_absolute_error

# %%
mean_absolute_error(y_test, y_pred)
# Out:
# 2.3038289239140632

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_test, y_pred)
# Out:
# 7.4566515092879255

# %%
 from sklearn.metrics import median_absolute_error

# %%
 median_absolute_error(y_test, y_pred)
# Out:
# 2.0999999999999996

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test, y_pred)
# Out:
# -0.011155051584671227
